# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import os, re
import matplotlib.colors as mcolors
import csv
from scipy.signal import savgol_filter, find_peaks
from scipy.optimize import curve_fit
from functions import *

def find_closest(value, series):
    return series.iloc[(series - value).abs().argsort()[:1]].values[0]

def find_edge_position(energy, intensity, monoE_min, monoE_max, smoothing_window, polyorder):
    """
    Finds the edge position in the given energy vs. intensity data obtained in Fluorescen mode###
        
      Parameter - energy: numpy array of energy values
    - intensity: numpy array of intensity values
    - smoothing_window: window size for Savitzky-Golay filter (default is 11)
    - polyorder: polynomial order for Savitzky-Golay filter (default is 3)

    Returns:
    - edge_position_idx: index of the detected edge position
    """
    # Step 1: Normalize the intensity data
    normalized_data = intensity / np.max(intensity)
    
    # smooth the data
    #smoothed_data = savgol_filter(normalized_data, smoothing_window, polyorder)
    
    # Step 2: Calculate the first derivative
    first_derivative = np.gradient(normalized_data)
    
    # Step 3: Find the index of the maximum in the first derivative
    max_index = np.argmax(first_derivative)

    if monoE_min <= energy[max_index] <= monoE_max:
        edge_position = energy[max_index]  # Access energy value directly using the index
        
    else:
        edge_position = 0
        print("Warning: No valid maximum found within the specified energy range.")
    
    
    return edge_position


def find_edge_position_PVfit(energy, intensity, monoE_min, monoE_max, smoothing_window, polyorder):
    """
    Finds the edge position in the given energy vs. intensity data obtained in Fluorescen mode###
        
      Parameter - energy: numpy array of energy values
    - intensity: numpy array of intensity values
    - smoothing_window: window size for Savitzky-Golay filter (default is 11)
    - polyorder: polynomial order for Savitzky-Golay filter (default is 3)

    Returns:
    - edge_position_idx: index of the detected edge position after fitting with a gaussian peak
    """
    # Step 1: Normalize the intensity data
    normalized_data = intensity / np.max(intensity)
    # smooth data
    smoothed_data = savgol_filter(normalized_data, smoothing_window, polyorder)
   
    # Step 2: Calculate the first derivative
    first_derivative_smooth = np.gradient(smoothed_data)
    first_derivative = np.gradient(normalized_data)

    # Step 3: Find the index of the maximum in the first derivative
    max_index = np.argmax(first_derivative)
    
    # Step 4: Check if the max_index falls within the specified range
    if monoE_min <= energy[max_index] <= monoE_max:
        # Step 5: Fitting the curve to obtain the maximum of the first derivative within the range
        # Limit the data to the specified energy range
        edge = energy[max_index]
        energy_range_mask = (energy >= edge-5) & (energy <= edge+5)
        energy_limited = energy[energy_range_mask]
        first_derivative_smooth_limited = first_derivative_smooth[energy_range_mask]
              
        
        # Initial guess for the pseudo-Voigt parameters: [A, x0, sigma, gamma, eta]
        Amplitud = 1
        x0 = energy[max_index]
        sigma = np.std(energy) / 10
        gamma = sigma
        eta = 0.5
        initial_guess = [Amplitud, x0, sigma, gamma, eta]

        try:
            # popt: This is an array of the optimal values for the parameters of the pseudo_voigt function
            # _: This is an array of the estimated covariance of popt, which is often ignored
            # *popt syntax unpacks the optimized parameters so that they are passed
            #  as individual arguments to the pseudo_voigt function
            ##without masking the data
            #popt, _ = curve_fit(pseudo_voigt, energy, first_derivative_smooth, p0=initial_guess)
            #Amplitud, x0, sigma, gamma, eta = popt
            #fit_curve = pseudo_voigt(energy, *popt)

            ##masking the data to only fit a peak close to the maximum value
            popt, _ = curve_fit(pseudo_voigt, energy_limited, first_derivative_smooth_limited, p0=initial_guess)
            Amplitud, x0, sigma, gamma, eta = popt
            fit_curve = pseudo_voigt(energy, *popt)


            # The edge position is the center of the fitted pseudo-Voigt curve
            edge_position = x0
            
        except RuntimeError:
            # Handle case where the fitting fails
            edge_position = energy[max_index]
            fit_curve = first_derivative
            print(f'The Edge position is obtained without fitting the first derivative with the PV function')

    else:
        # Handle the case where max_index is outside the specified range
        edge_position = 0
        fit_curve = first_derivative
        print("Warning: max_index is outside the specified energy range. Curve was not fitted.")
    
    return edge_position, fit_curve

def find_edge_position_second_derivative(energy, intensity, monoE_min, monoE_max, smoothing_window, polyorder):
    """
    Finds the edge position in the given energy vs. intensity data obtained in Fluorescen mode###
        
      Parameter - energy: numpy array of energy values
    - intensity: numpy array of intensity values
    - smoothing_window: window size for Savitzky-Golay filter (default is 11)
    - polyorder: polynomial order for Savitzky-Golay filter (default is 3)

    Returns:
    - edge_position_idx: index of the detected edge position
    """
    # Step 1: Normalize the intensity data
    normalized_data = intensity / np.max(intensity)
    
    smoothed_data = savgol_filter(normalized_data, smoothing_window, polyorder)
    #first_derivative = np.gradient(smoothed_data)
    first_derivative = np.gradient(normalized_data)
    
    # Step 3: Find the index of the maximum in the first derivative
    max_index = np.argmax(first_derivative)
    
    ## Step 4: Calculate the second derivative
    second_derivative = np.gradient(first_derivative)
    
    ## Step 5: Find the zero-crossing in the second derivative near the maximum
    zero_crossing_indices = np.where(np.diff(np.sign(second_derivative)))[0]
    
    # Filter zero_crossing_indices to those between monoE_min and monoE_max
    valid_indices = [idx for idx in zero_crossing_indices if monoE_min <= energy[idx] <= monoE_max]
    
    if not valid_indices:
        raise ValueError("No valid edge position found within the specified energy range.")
    
    # Step 7: Find the zero-crossing closest to the maximum in the first derivative
    edge_position_idx = valid_indices[np.abs(np.array(valid_indices) - max_index).argmin()]
    edge_position = energy[edge_position_idx]  # Access energy value directly using the index
    
    return edge_position #, second_derivative

def gaussian(x, A, x0, sigma):
    """
    Creates a Gaussian curve with the given parameters
    A is the amplitude.
    sigma is the standard deviation
    x0 is the center of the peak
    x is the data
    Returns:
    The Gaussian curve
    """
    Gaussian = A * np.exp(-(x - x0)**2 / (2 * sigma**2))
    return Gaussian

def lorentzian(x, A, x0, gamma):
    """
    Creates a Lorentzian curve with the given parameters
    A is the amplitude.
    gamma is the half-width at half-maximum
    x0 is the center of the peak
    x is the data
    Returns:
    The Lorentzian curve
    """
    Lorentzian = A * (gamma**2) / ((x - x0)**2 + gamma**2)
    return Lorentzian

def pseudo_voigt(x, A, x0, sigma, gamma, eta):
    """
    Creates a Pseudo Voigt curve with the given parameters
    to fit the data
    x is the data to be fitted
    A is the amplitud
    x0 is the center of the curve
    sigma is the standard deviation for the Gaussian curve
    gamma is the half-width at half-maximum for the Lorenztian
    eta is the between 0-1 determines the Lorentzian contribution of the PV curve
    Returns:
    The PV curve fitting
    """
    PV = eta * lorentzian(x, A, x0, gamma) + (1 - eta) * gaussian(x, A, x0, sigma)
    return PV

# %% [markdown]
# ## References from literature to calculate the edge position related to an oxidation state

# %% [markdown]
# ### Ni XAS Ref from literature - Extraction of the edge position

# %%
search_string = "Ni_REF_XAS.dat"

monoE_min = 8325
monoE_max = 8352

#edge = 8333
#smooth = "no"
# Ni K-edge is at 8.33 KeV

#Smoothing parameter needed 
# smoothing_window: controls the number of points used to fit each polynomial. 
# !should always be an odd number
# polyorder: defines the degree of the polynomial used
smoothing_window, polyorder = 17, 1

## Walk through the current directory and subdirectories
#for root, dirs, files in os.walk("."):
#    for i, file in enumerate(files):
#        if search_string in file:
#            file_path = os.path.join(root, file)                    
#print(file_path)

# Walk through the current directory and all its subdirectories
for root, dirs, files in os.walk("."):
    for i, file in enumerate(files):
        file_path = os.path.join(root, file)
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                file_content = f.read()
                if search_string in file_content:
                    print(f"Found '{search_string}' in: {file_path}")
        except (UnicodeDecodeError, PermissionError) as e:
            # Skip files that cannot be read due to encoding issues or permissions
            print(f"Skipped {file_path} due to {e}")
result_df = pd.read_csv(file_path, sep='\t')

cmap = plt.cm.viridis
norm = mcolors.Normalize(vmin=0, vmax=(result_df.shape[1]-1) / 2)

energ_calib_Ni_REF_XAS_list = []

first_derivative_list = []  # To store the first derivatives of all curves

if 'Energy' in result_df.columns:
    # Get a list of columns excluding 'Energy'
    columns_to_process = [col for col in result_df.columns if col != 'Energy']
    
    for column in columns_to_process:
        #for idx, value in enumerate(result_df[column]):    

        # Apply Savitzky-Golay filter to smooth the data
        smoothed_data = savgol_filter(result_df["I"], smoothing_window, polyorder)
        
        # Compute the first derivative of data and the smoothed data
        first_derivative_data = np.gradient(result_df["I"])
        first_derivative_smooth = np.gradient(smoothed_data)

        # Plot the first derivative
        plt.plot(x, first_derivative_data, label=f'{column} derivative', linewidth=1.5 )
        plt.plot(x, first_derivative_smooth, label=f'{column} smoothed data', linestyle='dotted', linewidth=2.5 )
        #plt.plot(x, fit_curve, label=f'{column} fitted derivative', linestyle= 'solid', linewidth=1.5 )
        #plt.plot(x, second_derivative, label=f'{column} Second derivative', linestyle= ':', linewidth=1.5 )
            
        energ_calib_Ni_REF_XAS_list.append((column, float(edge_position), float(edge_position_fit), float(edge_position_2nd_derivative)))
        #energ_calib_Ni_REF_XAS_list.append((column,float(edge_position)))#, float(edge_position_fit)))
        
#print(energ_calib_Ni_REF_XAS_list)    
plt.xlabel('Energy (eV)')
plt.ylabel('First Derivative')
plt.title('First Derivative of Smoothed Data')
plt.legend()
#plt.xlim(8320,8380)
plt.show()

#Save the edge data in a new file
filename = "Ni_REF_XAS_position_derivative.dat"  #'sample_data.dat'

# Open the file in write mode
with open(filename, 'w') as file:
    # Write the header
    file.write('Reference,Edge Energy (eV),Edge Energy (eV)_PVfit_of 1derivative, Edge Energy (eV)_2derivative \n')
    print(f'Reference,Edge Energy (eV),Edge Energy (eV)_PVfit_of 1derivative, Edge Energy (eV)_2derivative \n')
    # Write each tuple in the data
    for condition, energy, energy_fit, energy2_derivative in energ_calib_Ni_REF_XAS_list:
        file.write(f'{condition},{energy},{energy_fit},{energy2_derivative} \n')
        print(f'{condition},{energy},{energy_fit},{energy2_derivative} \n')

print(f'Data saved to {filename}')


# Extract x and y values
x_labels = [item[0] for item in energ_calib_Ni_REF_XAS_list]
y_1_derivative = [item[1] for item in energ_calib_Ni_REF_XAS_list]
y2_fit_1_derivative = [item[2] for item in energ_calib_Ni_REF_XAS_list]
y3_2_derivative = [item[3] for item in energ_calib_Ni_REF_XAS_list]

# Create a scatter plot
plt.scatter(x_labels, y_1_derivative, label = "First derivative")
plt.scatter(x_labels, y2_fit_1_derivative, label = "PV fitting First derivative")
plt.scatter(x_labels, y3_2_derivative, label = "Sendond derivative zero")
plt.xticks(rotation=45, ha='right')
plt.ylabel ("Edge energy of the Ni K-edge_derivative / eV")
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("Ni REF edge_derivative")
plt.savefig('Ni_REF_XAS_edge_derivative.png')
# Out:
# Skipped ./LogBook_2024_07_23_Sample1_Cu-6Sm_2024_07_26_0745.pdf due to 'utf-8' codec can't decode byte 0x9c in position 72: invalid start byte
# Found 'Ni_REF_XAS.dat' in: ./Analysis.ipynb
# Skipped ./XRD_Ru_CGO_main_CeOx_peak.pdf due to 'utf-8' codec can't decode byte 0xac in position 10: invalid start byte
# Skipped ./LogBook_2024_07_23_Sample1_Cu-6Sm_2024_07_27_1035.pdf due to 'utf-8' codec can't decode byte 0x9c in position 72: invalid start byte
# Skipped ./__pycache__/functions.cpython-310.pyc due to 'utf-8' codec can't decode byte 0xe3 in position 16: invalid continuation byte
# Skipped ./S1_Cu_6Sm/Cu_REF_NEXAFS.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S1_Cu_6Sm/Cu_NEXAFS_S1.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S1_Cu_6Sm/Cu_REF_energy_shift.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S1_Cu_6Sm/Cu_EXAFS_S1.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S1_Cu_6Sm/Ce_NEXAFS_S1.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./.git/index due to 'utf-8' codec can't decode byte 0x94 in position 11: invalid start byte
# Skipped ./.git/objects/a5/c7176e0b3f421bb4821d83145f003ddebc782d due to 'utf-8' codec can't decode byte 0xd9 in position 7: invalid continuation byte
# Skipped ./.git/objects/a5/afb6486d28c2b492f735c6049331a3f4d8ec11 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/a5/73a281bc624789b4052581864e09b1b5807bec due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/68/ffb83b00326fdeabaf1d6dabdbd1075c735d74 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/68/dab61e334aefa295570992f26a86ede12688c1 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/68/4034f1b386ae630df4df154b09fd11436a75a6 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/68/9e8a773ef0f48bec0595eb7417c77b201b0b31 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/68/029afb8e78a53faaa4ee0eac2f6dca8ede4d8f due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/a8/fac4806bc8556ce2d7feb1351f0eacb7916175 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/a8/e1fd9a8827516a591f193511d83394a7d89abc due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/a8/8493b800c30f9c07a2bee4aac3d54b7e66cecd due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/a8/d6759baca00bc0448314835d060fb026ece8c1 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/a8/4a3bc107c920d50f35f428178082af8db26c41 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/5d/a981db9d97c9cd868bda506f05a1d173fa4525 due to 'utf-8' codec can't decode byte 0xb6 in position 8: invalid start byte
# Skipped ./.git/objects/5d/a5d0adc331b3bbf60ce1102ae2646806287719 due to 'utf-8' codec can't decode byte 0xdd in position 3: invalid continuation byte
# Skipped ./.git/objects/14/c7a683c8822b6315b2cc97d11532794aad3638 due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/14/1554b1429d63f1ade9f7ff75d034ccf7a70f14 due to 'utf-8' codec can't decode byte 0x90 in position 3: invalid start byte
# Skipped ./.git/objects/14/b68cf6704f5e8a85e9993276edbf648705de77 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/14/7ded8ff4ec95ae55ac70f9e9cd6f13ce50feff due to 'utf-8' codec can't decode byte 0xda in position 3: invalid continuation byte
# Skipped ./.git/objects/14/8cbad77bb14d9da5ec7d28b53d525ea2e08a71 due to 'utf-8' codec can't decode byte 0xe5 in position 2: invalid continuation byte
# Skipped ./.git/objects/14/62dd91f9506f9b8b34dafb42d28f66c36d4c24 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/14/38a57449b3015cb449c16c0469881b79cb2f47 due to 'utf-8' codec can't decode byte 0xda in position 3: invalid continuation byte
# Skipped ./.git/objects/d1/7d0ffe555fbdbeec36a1d8185769aeb82411d3 due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/d1/3af44f9fffa8803010f8f53ebe548eef9cc611 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/d1/8ee5e299e5160f073741d080ac5e6f651a444a due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/d1/3dc997ecec760a31347c45d27f17c267c5239c due to 'utf-8' codec can't decode byte 0xd9 in position 3: invalid continuation byte
# Skipped ./.git/objects/d1/e8ad6b84a3ad08c2e0e2c724a5b58499131a46 due to 'utf-8' codec can't decode byte 0xb3 in position 8: invalid start byte
# Skipped ./.git/objects/dd/6f46c21865cbdb542d7b541eda4a4329a380c8 due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/dd/58659a51dfdc6bf556845fb3f9065a003a35b9 due to 'utf-8' codec can't decode byte 0xb3 in position 8: invalid start byte
# Skipped ./.git/objects/dd/0338501138bb66f7334311debee61eefa65bca due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/dd/bc5b0d2fa9d4173f0b4e0c50f526f95bfec009 due to 'utf-8' codec can't decode bytes in position 2-3: invalid continuation byte
# Skipped ./.git/objects/dd/64da633c8012e63129a5f7732a8f41d905039a due to 'utf-8' codec can't decode byte 0x91 in position 3: invalid start byte
# Skipped ./.git/objects/dd/a0168ec49e53c30174fa1888a4105eee482bb3 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/dd/a2c5d4394954bdf941196eb34699b935ce9ed5 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/a1/a09ed6893b29ebfc8dcd5c28e989eca2754fc9 due to 'utf-8' codec can't decode byte 0xe7 in position 16: invalid continuation byte
# Skipped ./.git/objects/a1/18a624aad0bd7ffb3e39412001fcb439c5ef3b due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/a1/913b08aa101a6d7d3d647d15cb8c41e631af0b due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/a1/41da2a77b3cd097a5337c0385c39c5b376fc03 due to 'utf-8' codec can't decode byte 0xd5 in position 6: invalid continuation byte
# Skipped ./.git/objects/98/64f4dca14977bfac81fc755e273cb3fcd42173 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/98/e08d44c6a023d02a1d669a5a30a3717dfb48bb due to 'utf-8' codec can't decode byte 0xb3 in position 8: invalid start byte
# Skipped ./.git/objects/98/211f09aabd7604b7266981833dfe8a85e4bda8 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/b8/16e5c1d9f6f692cf20c171abb800ebffa40306 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/b8/2517c938c8b11eafa66df16e580ed37a194451 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/b8/6fd6558f5ec53181a126449db36794ef8ff651 due to 'utf-8' codec can't decode byte 0xdb in position 3: invalid continuation byte
# Skipped ./.git/objects/b8/9fd98210e023fee7bac11ddecb5edf7fa5feda due to 'utf-8' codec can't decode byte 0x96 in position 6: invalid start byte
# Skipped ./.git/objects/b8/6c52563ff54b095df00458c0c0821eb5055c81 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/e3/cba0c24018a76eeaa49399eaff65b5ea68f883 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/e3/42f2d5fb4688e9d1bf1311d2a868a0b8e6b92a due to 'utf-8' codec can't decode byte 0x91 in position 3: invalid start byte
# Skipped ./.git/objects/e3/ce3a87007d054b7a2ed264c49ccd3162c0fc99 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/e3/01dcf1d8ec31115e10cd4bef4d50df78e1e0e6 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/e3/a034920d8716e1709859ff0ad2f10bd5553b00 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/e3/85adbb468dc64681f1a1dd620c37979a265fa4 due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/e3/0f41a748f3762daf58b005fac772675a8edc0b due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/e3/234ba769c687e3bb268dfcb1a42ea88abdd0e4 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/20/d03e2f61a7ce004499e264a84f5a2d3c8ebfc1 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/20/ee84d597290075a226b94cf3d261e637d47322 due to 'utf-8' codec can't decode byte 0xb3 in position 8: invalid start byte
# Skipped ./.git/objects/20/ae2b6fab9242c307440ac9027fd9f6249456aa due to 'utf-8' codec can't decode byte 0xa3 in position 19: invalid start byte
# Skipped ./.git/objects/de/0313dfc26ed1c956c500fec940b0be7826f88f due to 'utf-8' codec can't decode byte 0xb5 in position 8: invalid start byte
# Skipped ./.git/objects/de/8a9c21c87bb30f4f618a55bb1ea3fb05304851 due to 'utf-8' codec can't decode byte 0xca in position 3: invalid continuation byte
# Skipped ./.git/objects/de/23178ed946ec45d0f650b41fc7998630baa6cb due to 'utf-8' codec can't decode byte 0xf1 in position 12: invalid continuation byte
# Skipped ./.git/objects/de/432d820053f19f5cb800e4e1dffda67ca10bf9 due to 'utf-8' codec can't decode byte 0xf1 in position 22: invalid continuation byte
# Skipped ./.git/objects/e0/b098e878be32abf0d62e55cd3c09f6102dc1c2 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/e0/1e0b7bf882453e7620780c17705d21e820e791 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/e0/897eb8649c637e429917b31d92b9b2812b8c80 due to 'utf-8' codec can't decode byte 0x90 in position 3: invalid start byte
# Skipped ./.git/objects/e0/feb957e3b78ad2905d9a04a4702fbb0413f833 due to 'utf-8' codec can't decode byte 0xe5 in position 2: invalid continuation byte
# Skipped ./.git/objects/e0/868a64cea10fde5041371108b81ba9a3e994e2 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/e0/44181889ea045c8464503bcc44aaaf937300cc due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/97/f82f1e8f377e0f189effb4565ab4e9166bad96 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/97/d234b40518b871cbedfafe7e89ba3ca696f4d4 due to 'utf-8' codec can't decode byte 0x8c in position 2: invalid start byte
# Skipped ./.git/objects/97/0ba956e78dc6df662b9bf200ddd6af0c8717aa due to 'utf-8' codec can't decode byte 0xd1 in position 23: invalid continuation byte
# Skipped ./.git/objects/97/c5aa3456a130f7abc87f3c2e2f6f9115e4df73 due to 'utf-8' codec can't decode byte 0xb3 in position 8: invalid start byte
# Skipped ./.git/objects/97/7cad282883130389df00ef9c74ea94ccbee5d8 due to 'utf-8' codec can't decode byte 0x90 in position 3: invalid start byte
# Skipped ./.git/objects/71/d5dfdeae07f23d3db720364c2f96d03e7d4d9f due to 'utf-8' codec can't decode byte 0xda in position 3: invalid continuation byte
# Skipped ./.git/objects/71/ba709e779a1d9172739f66ec39cf33b0e068fd due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/71/0dad80f9bcc385c533cc49c7b5e9af07b41e51 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/71/763325d35fbdbe81e3ecd55ba5c05e9e8446d2 due to 'utf-8' codec can't decode byte 0x95 in position 2: invalid start byte
# Skipped ./.git/objects/71/e58cd802aa3dffb8871712bf260ffd9c878279 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/9f/04f5e09b1393e83e631ac3552ea0cdff7dbe99 due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/9f/99e9e350ae67fb9c7e7dd19d6ef6e4fb879ba0 due to 'utf-8' codec can't decode byte 0xed in position 2: invalid continuation byte
# Skipped ./.git/objects/9f/e28500cb28860fce3fbc1c9ae4d130f5c32ee1 due to 'utf-8' codec can't decode bytes in position 2-3: invalid continuation byte
# Skipped ./.git/objects/d0/7893fa2ee880745fa77bb14c6a63843a5147be due to 'utf-8' codec can't decode byte 0xd1 in position 22: invalid continuation byte
# Skipped ./.git/objects/d0/66175a352d90c2fb99be7625689234b58cdf84 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/d0/d5d3e678e63e6c21626cb238f465042a6d967d due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/d0/c21ebd5ae264e99576b17c0fa048d701d22c99 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/89/62e3e40fed8360d66bea1335d3b13de0a68c4f due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/89/6a8578670cc69fdbb82350d9c2255053549c78 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/89/6d1c957b6f3629f18592d0bd227ec335305309 due to 'utf-8' codec can't decode byte 0xd1 in position 22: invalid continuation byte
# Skipped ./.git/objects/89/78d0b5dabc882192e03909c237f134aadeb28f due to 'utf-8' codec can't decode byte 0xb3 in position 8: invalid start byte
# Skipped ./.git/objects/0f/f721caf975a4cf336002fa17edfa87affd07ed due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/0f/88165a56817589e5ad167ba5eb906465d64062 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/0f/8139eef454389c2e8984c85404e32adbfecbf2 due to 'utf-8' codec can't decode byte 0xbc in position 2: invalid start byte
# Skipped ./.git/objects/4c/92caae1dc109745c400ccbf8d3215452b8bb4a due to 'utf-8' codec can't decode byte 0xb6 in position 8: invalid start byte
# Skipped ./.git/objects/4c/e06af39faa052c43bdefe97b62d68c4d306f82 due to 'utf-8' codec can't decode byte 0xd9 in position 3: invalid continuation byte
# Skipped ./.git/objects/4c/cd18c3b7f3efd38f17be0c4815a9f1244366a8 due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/4c/c1f68eed95e991d39b5179ceda4856ea72bd90 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/4c/6bf3aadd131a5e3537e6ab706bf2b91d37a459 due to 'utf-8' codec can't decode bytes in position 2-3: invalid continuation byte
# Skipped ./.git/objects/4c/e277190e68fbbd488a67a152da5929884690c6 due to 'utf-8' codec can't decode byte 0xb5 in position 8: invalid start byte
# Skipped ./.git/objects/8e/66b850d24fbe8b3cf3ff2a15f5ae1946b1372e due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/8e/96ab4c8b7d74948f41d9bcaa3ec31d8464a38e due to 'utf-8' codec can't decode byte 0xbc in position 2: invalid start byte
# Skipped ./.git/objects/8e/a763fb4c32b43407b507b7fe780ced500d64bf due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/8e/16c360c6914b88bc14ad37b45e8b595934a5f4 due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/8e/4e704e6003fff0bc7901e30908ad878847140e due to 'utf-8' codec can't decode byte 0xb6 in position 8: invalid start byte
# Skipped ./.git/objects/8e/ae6f0404f562551196a301d0ad0e3857058f64 due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/c9/1e26b5b6fb58e38d3b4aa1204ce775e45e0ac3 due to 'utf-8' codec can't decode byte 0xb0 in position 9: invalid start byte
# Skipped ./.git/objects/c9/a00628ca8678391f79a5897d1cbc7bd33ac8c4 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/c9/2ca5434c22be50e08ed7b022d0a71aa92f22b6 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/c9/35ed88d64b3c339a34c49fe09d921aea56cfe8 due to 'utf-8' codec can't decode byte 0x8e in position 5: invalid start byte
# Skipped ./.git/objects/bc/f79c606ed0ab52404266cd9bc9d39e98df5ad8 due to 'utf-8' codec can't decode byte 0xda in position 3: invalid continuation byte
# Skipped ./.git/objects/bc/5f73825169a4c7b7ef998e1d87914c3dcbf71b due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/bc/f383b67573022fdde1bf200fb57285a6ea05d3 due to 'utf-8' codec can't decode byte 0xd9 in position 3: invalid continuation byte
# Skipped ./.git/objects/bc/862559b77e7d521ca9fb5df1d3afa70fe6296a due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/76/cb7f37ae1f6b2aa6b8ded9add543734afe52b5 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/76/74da270449ba78a624f480524de25b5f6e2565 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/76/6737e4faa353650ad930762949fcb98be10516 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/76/2f0b07cce63e4041479ebf32aabf74d7cf3957 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/76/169f4ed95c11ca572786522958b971931bdebf due to 'utf-8' codec can't decode byte 0xd6 in position 3: invalid continuation byte
# Skipped ./.git/objects/d5/602b4028e24fb67f41ae31ba56440da40c7351 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/d5/7c5c20759e353c0f94d89cd5bf2264dd5d5ce1 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/d5/32b5cf3c3b36b2f5c186e7b512b76037a23bec due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/d5/2a28f2ef99bc9cba54367c75de06203db4501e due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/d5/ebae4489549952c9d00dd1dc01c4c3a6b749ec due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/21/68ee0034a463d6fc40aaeb752c8843c1f62f83 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/21/dc514f159bc1010c16cf00bc460bdf14804e4d due to 'utf-8' codec can't decode byte 0xd4 in position 3: invalid continuation byte
# Skipped ./.git/objects/21/cac95f0ff490e4ae5be322525748272a066122 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/21/a14050e06514514b1982b00ee84bf7a78319da due to 'utf-8' codec can't decode byte 0xed in position 2: invalid continuation byte
# Skipped ./.git/objects/21/4033d78936b5c9e2e15e184b40fc79e9865cf7 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/21/ef7ab16099c4ad3c7d2393bd9594a03f79d13d due to 'utf-8' codec can't decode byte 0xdb in position 3: invalid continuation byte
# Skipped ./.git/objects/e7/e27ee3ae2ab0d7745f81e3383946b13a071e8f due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/01/06560edbec460c280239345a02a304c2a706b7 due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/01/5cfa59fba6c042e14c6b6f62e5d1dadea7b153 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/01/a77f39cb87cac41af7bf3b6f26e69435e2e0fe due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/01/bbf46047cfe4e470c5f257bc00379c1038460a due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/8b/0f69ca92b1cb865a856649aab6dc274a87d53e due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/8b/8c696f9d58a4d946f3006aae76208f275c13a3 due to 'utf-8' codec can't decode byte 0x90 in position 3: invalid start byte
# Skipped ./.git/objects/8b/137891791fe96927ad78e64b0aad7bded08bdc due to 'utf-8' codec can't decode byte 0xca in position 3: invalid continuation byte
# Skipped ./.git/objects/8b/3ff2f053e4b79af2622e7562bd31e3cc3ef6d8 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/8b/4476c175aeb727b6a0f8f9ab4bcf86e82fec76 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/pack/pack-1b737d70c11ebf278d9efecc059ada9f89bbe453.pack due to 'utf-8' codec can't decode bytes in position 11-12: invalid continuation byte
# Skipped ./.git/objects/pack/pack-1b737d70c11ebf278d9efecc059ada9f89bbe453.rev due to 'utf-8' codec can't decode byte 0xd5 in position 31: invalid continuation byte
# Skipped ./.git/objects/pack/pack-71763b6cc031355caf3739185b3476da6e8ca8f3.pack due to 'utf-8' codec can't decode byte 0x9c in position 15: invalid start byte
# Skipped ./.git/objects/pack/pack-1b737d70c11ebf278d9efecc059ada9f89bbe453.idx due to 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipped ./.git/objects/pack/pack-71763b6cc031355caf3739185b3476da6e8ca8f3.rev due to 'utf-8' codec can't decode byte 0x8a in position 51: invalid start byte
# Skipped ./.git/objects/pack/pack-8b6e376b11c3d09e4279758d6f0473526711b103.idx due to 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipped ./.git/objects/pack/pack-71763b6cc031355caf3739185b3476da6e8ca8f3.idx due to 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
# Skipped ./.git/objects/pack/pack-8b6e376b11c3d09e4279758d6f0473526711b103.pack due to 'utf-8' codec can't decode byte 0x95 in position 12: invalid start byte
# Skipped ./.git/objects/pack/pack-8b6e376b11c3d09e4279758d6f0473526711b103.rev due to 'utf-8' codec can't decode byte 0x8b in position 32: invalid start byte
# Skipped ./.git/objects/51/74ecb83213a71e6b4e8fbb138f217fdd738c32 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/51/8c9c2ac2079b5609dfa473b302c04a13dd9c5b due to 'utf-8' codec can't decode byte 0xb3 in position 8: invalid start byte
# Skipped ./.git/objects/90/dcca1e0ebe507381c081b2f7b0634d7f83699a due to 'utf-8' codec can't decode byte 0x95 in position 2: invalid start byte
# Skipped ./.git/objects/90/9ae3855bd707e1d0ebe36b0ec6d073859c776b due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/90/c28b9b761ef06a38e2d8879a937d06a1f5f351 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/90/2cbf5daec979cfbbdbb036be0c3b9227f5517d due to 'utf-8' codec can't decode byte 0x95 in position 2: invalid start byte
# Skipped ./.git/objects/1b/2d8e99f170e891075e37f96757654e47bfd7bc due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/1b/5f419dbc8e73ebf3a883f32f57aa6fa6c34d6b due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/1b/67725f5f369a0c82a7d2eef383f65b87754b4d due to 'utf-8' codec can't decode byte 0xe7 in position 16: invalid continuation byte
# Skipped ./.git/objects/24/e6154ea2ea974dcc91701801ba4da6466b35a8 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/24/23eaa4605d62c1ffba27629b1c5411f9a96551 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/24/d43cb5598afe4f02a134645cc77d66e2440506 due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/ba/2e2b34343cbd8c92de2fee711901572c8cbbaf due to 'utf-8' codec can't decode byte 0xdb in position 3: invalid continuation byte
# Skipped ./.git/objects/ba/f4cd2013ed26baaf904fa1a12aaa36565130b1 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/ba/3237e8a6f405675a9c4da48479271575c8aaea due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/ba/01cc5a73845eec2cdc8d099381e73f106a97c1 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/6d/9814718b1a82dc109b3d2d7e8f8a5348ea5c19 due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/6d/a852d6dec41e4e5de6700089885b4311153ec7 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/6d/2fa94d354a6e2e85f756190a3e04e14fd44486 due to 'utf-8' codec can't decode byte 0xb3 in position 8: invalid start byte
# Skipped ./.git/objects/6d/7b9c67994f491f14b4931db392f4b036604022 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/6d/c232076cd12200dd358ff46e406291160caf2d due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/77/2e102a6aece4d3378c6f2ec4f60a3f658e6ce7 due to 'utf-8' codec can't decode byte 0xd1 in position 21: invalid continuation byte
# Skipped ./.git/objects/77/7836a179393942f7e9d40ca6c2b53c61aeb0a3 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/77/0181372a21084d3c61ad25d43a01dd68d26b11 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/06/12f1e53caf90872a76b3bb881c3733059a94fe due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/06/dc61815b3b701a3ffc98d84e7588a11d7e6ff1 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/cf/73822f3d1b4eb90e668e487e7619a37755022d due to 'utf-8' codec can't decode byte 0xd1 in position 23: invalid continuation byte
# Skipped ./.git/objects/cf/7931149b967cd6904e790fbf01720b5838ed16 due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/cf/ec71b6b73c3b73c56e98a777e3c1b41988bd44 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/cf/b02e42bcfc59c454bcbba55c3b851da8fd3505 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/cf/4ef0f17b61897988ee7acefda530183c3496e6 due to 'utf-8' codec can't decode byte 0xed in position 2: invalid continuation byte
# Skipped ./.git/objects/cf/c936ef72cbcdc69396e6dea6ea1408f9350465 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/cf/9215cde5722ebfe06b51ed6cb851fda0c2c3ff due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/cf/2be74d721de72a3adfe9433de6fb29976a5257 due to 'utf-8' codec can't decode byte 0xe7 in position 16: invalid continuation byte
# Skipped ./.git/objects/72/27aa60f3ccc5cafeea1665c4dec552393b3028 due to 'utf-8' codec can't decode byte 0xc3 in position 18: invalid continuation byte
# Skipped ./.git/objects/72/467d3d0f69dc5a9a72711f105fed8074b2d5e2 due to 'utf-8' codec can't decode byte 0xcb in position 3: invalid continuation byte
# Skipped ./.git/objects/72/258993ae8b2154d842f4b03efcca3b72b805a1 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/72/196defe1c01e3cc059a4be6856eb28702d7596 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/72/27d554bc01ecea48810c88fb9de13ab85a79d1 due to 'utf-8' codec can't decode byte 0xcb in position 27: invalid continuation byte
# Skipped ./.git/objects/72/7ebb50d09efc9d9fc021bdb15a0a2ccfd7be6b due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/72/b877bfa915244de702f0777464af0b07428e85 due to 'utf-8' codec can't decode byte 0x90 in position 3: invalid start byte
# Skipped ./.git/objects/54/3f17ef2e70d953fd9c5722ae7e4eac70bfae2d due to 'utf-8' codec can't decode byte 0xdb in position 3: invalid continuation byte
# Skipped ./.git/objects/54/adf7c6b8e5e3fd07df4f1f2fc5cf6cb09ed06e due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/54/6ab9609da14a231d13dca9534c41222e04c19f due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/54/31b83e8305ddf7edaf6dc2524cfaba89d7f792 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/54/3375f1760e102128d6cded5d9614d4eb55d2fa due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/54/72fdc814db16ee7bc1d69510a626fbc26896c4 due to 'utf-8' codec can't decode byte 0xe5 in position 2: invalid continuation byte
# Skipped ./.git/objects/54/802a05ef574d6f68512ac8f078e4c161fa3456 due to 'utf-8' codec can't decode byte 0xdb in position 3: invalid continuation byte
# Skipped ./.git/objects/54/e0f9fb2555acd35e4d2f217acca404b3621860 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/ec/d4e682ef3f5e943c268064a483132831f84397 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/ec/64796c2fd59a96681b80ee01611a3db68d12f0 due to 'utf-8' codec can't decode byte 0xd1 in position 23: invalid continuation byte
# Skipped ./.git/objects/ec/c539e9bd08e78ea021268fe23784f998ebfd96 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/ec/c85d0dcde0fffd10de65418b3e1ed989998585 due to 'utf-8' codec can't decode byte 0xd1 in position 22: invalid continuation byte
# Skipped ./.git/objects/ec/eb3643764f4522c81694a88cf6631a01c1bda0 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/ec/d128a47c060462fd875870cb997aa67fe58bd4 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/ec/df669f10fc24a26e56dc817bdaf24e4e7e9beb due to 'utf-8' codec can't decode byte 0xd1 in position 23: invalid continuation byte
# Skipped ./.git/objects/ec/570b7e9a80f6233bee264f83013d007a88d91f due to 'utf-8' codec can't decode byte 0x91 in position 3: invalid start byte
# Skipped ./.git/objects/8d/7b1950fb53af37ff734dc12953749ca444ab54 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/8d/8294c55c6a5b96a3b9e4d34e2bd4f219175e47 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/8d/edc3ee6f540855359e182ecafc2edc19239fc6 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/8d/2d049a2f3a233832975ed952cf1760984bd18f due to 'utf-8' codec can't decode byte 0xd9 in position 3: invalid continuation byte
# Skipped ./.git/objects/d4/f61ae3cd066e447fae7bec4ef27de75e83c0b8 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/d4/5c462575cd92ef5c015db643c2ee21d25804a7 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/d4/d5d62dea7fe479ed22cf2c51c4a0aad4cc62e9 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/d4/7030ef58184813b2808cce81e0b733cc4f4c43 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/d4/82528a92d0f4c5fe139f557f630413437a9fd0 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/d4/399d7ade977e7efd5a839f2a74b577f3f09fca due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/d4/6e670436fb9bea55aeffebfcd33ef29ef192e8 due to 'utf-8' codec can't decode byte 0xdd in position 3: invalid continuation byte
# Skipped ./.git/objects/d4/abaf16f44a0b27ef1e530c36aa01deee5b4ff5 due to 'utf-8' codec can't decode byte 0xa3 in position 19: invalid start byte
# Skipped ./.git/objects/d4/2a848c66446a9a834ce9d15bd1a26e3c2a209a due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/2b/243eb8a07025fccc5210b76b3f4edb2615e999 due to 'utf-8' codec can't decode byte 0xb3 in position 8: invalid start byte
# Skipped ./.git/objects/2b/fb83308e9f33acbb5c7eb4691bc10cfaed5cb2 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/2b/bec0cae1cfd5d75e46192284d1fad10888d4c5 due to 'utf-8' codec can't decode byte 0xda in position 3: invalid continuation byte
# Skipped ./.git/objects/2b/0b00a3d2ef6eccbcb7dbdbf63c74f7017f9b4a due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/2b/ea90748b4e1e2788f30762466afcdc22aad617 due to 'utf-8' codec can't decode byte 0xa3 in position 18: invalid start byte
# Skipped ./.git/objects/0a/dd540ccd3a2978387538e6185b1ef7fde680b6 due to 'utf-8' codec can't decode byte 0xd9 in position 3: invalid continuation byte
# Skipped ./.git/objects/0a/22b87783a00c7704d3b611793bd77692e2e159 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/ca/64bf609ba288e31318f0c6a3becbf84d801db8 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/ca/9bf4ac5ff7fc2755d68b0c5d939bf3d2cefb79 due to 'utf-8' codec can't decode byte 0xb3 in position 8: invalid start byte
# Skipped ./.git/objects/ca/bfd88f91752c5e38a6e85b12abb447bb3bb143 due to 'utf-8' codec can't decode byte 0xdb in position 3: invalid continuation byte
# Skipped ./.git/objects/ca/aba6393c7d5ee3478165650d76b51f8d884cf2 due to 'utf-8' codec can't decode byte 0xda in position 3: invalid continuation byte
# Skipped ./.git/objects/6e/d95310c4e278badf1b4a124a81d122e07f24ef due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/6e/42d1de8195b887f9cab16ff8b65111476e777f due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/6e/30c71c658230ce1ff9e1909e1b00489572fd43 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/6e/0f71f5cb52df63906fc205e4f0b1210faca29a due to 'utf-8' codec can't decode byte 0xad in position 19: invalid start byte
# Skipped ./.git/objects/6e/da43314fc257f9cf72f6675453f9eb89d401c3 due to 'utf-8' codec can't decode byte 0x83 in position 6: invalid start byte
# Skipped ./.git/objects/6e/dd343da94e83c7c05daed5cd1380c4dac049ae due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/80/2a53e0d7820d72e3ec5a3a4f6670cb3f05a3df due to 'utf-8' codec can't decode byte 0x95 in position 2: invalid start byte
# Skipped ./.git/objects/b1/08f52a3d7fbf56226f00e61c446417349b1fa5 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/b1/fde3870329a5768d5560b55f6cdca948b94c5e due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/b1/c1ad93851d6c475c287814ab1adc1cdd254db4 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/b1/2ddc93658f832fa1092a4365c9f1ebaa53b912 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/b1/bae05e6cc315c495e356ae809e23d5444eebfc due to 'utf-8' codec can't decode byte 0xb5 in position 8: invalid start byte
# Skipped ./.git/objects/b1/04f887cf4003df3a5896d261f8e03792ff67c9 due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/b1/6ffd3e907f4f254c50793ffa0c1baec54912a1 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/b1/fef6dbf07c21ace379d2057cda15d8d4d0d9e8 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/b1/7caf3f4a701ee10b5fdb964bf11a9b12aae3d7 due to 'utf-8' codec can't decode byte 0xd7 in position 6: invalid continuation byte
# Skipped ./.git/objects/55/dc8b5bcc8ee2bd54b905d5dd706f3d550c4d77 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/55/7f5ed45e62874d9b795dc9e2860d7b62d01430 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/55/276278d892a6c9fa2f198a7ae5bbacf7a8cfac due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/d3/c707573cb4e4d56bb5b5fd69b88c7fe5352e63 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/d3/656aaef417507f589e943e48248c37b68354fd due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/d3/fcf954c99133b4210e0032bfcc4841aea98db5 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/39/1a8e74f63247a85107db4db3f59594ddf8340d due to 'utf-8' codec can't decode byte 0xd1 in position 22: invalid continuation byte
# Skipped ./.git/objects/39/2113f308f6fd907dedbb9d5d5637e161bb815e due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/39/94ef3af94579c5a8bee766427fc5cd7314b6ea due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/39/29495cd8dcfad639fe8743cb1313b8129aac8d due to 'utf-8' codec can't decode byte 0xd1 in position 23: invalid continuation byte
# Skipped ./.git/objects/39/bf0328153234407608b94d8806e73affde1081 due to 'utf-8' codec can't decode byte 0x9d in position 2: invalid start byte
# Skipped ./.git/objects/1a/30f674104bd22c4fcd21548a243ddff2e7fb16 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/1a/93b816cf402ed6270085823017f8313ec28b22 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/1a/a37e7cb8f31207448532054294bc5e16d54e37 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/1a/2d4a3034d037ca73f7a6a1dec6e6253601adc0 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/1a/fba87737fe32c1f8acc39dacd506f02351757e due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/1a/d16a142bf52dd6babcd460fe46cb9388ca6be8 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/1a/257fae759570cedec9e7e19be88d2d8bbac3f5 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/8f/3c1234a0e430b9f35de5ce0be21a1a7f213cb1 due to 'utf-8' codec can't decode byte 0xb3 in position 8: invalid start byte
# Skipped ./.git/objects/8f/c75852f75fffad6d6eb17a30b4a9886266e0bc due to 'utf-8' codec can't decode byte 0xc3 in position 6: invalid continuation byte
# Skipped ./.git/objects/8f/e58b28eea76e255852f4c89f339c0c6178c6b3 due to 'utf-8' codec can't decode byte 0xd1 in position 23: invalid continuation byte
# Skipped ./.git/objects/8f/93e308b25bb0803acada7121f820544d124ddd due to 'utf-8' codec can't decode byte 0xf1 in position 21: invalid continuation byte
# Skipped ./.git/objects/8f/3792f5a6d219b14bb5849eaf09f2581271ff9d due to 'utf-8' codec can't decode byte 0x90 in position 3: invalid start byte
# Skipped ./.git/objects/3b/a3bc5b8b9a1ca35f49c316ee3793bc779f9f2a due to 'utf-8' codec can't decode byte 0xd0 in position 3: invalid continuation byte
# Skipped ./.git/objects/88/9ec6d69032b9daeacde57fafb4432d0c6a7d2b due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/88/11342d619abee956789c6f336382f4a7d211c6 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/88/49a13956cacaf558598d3722c584a5f7d6ffdb due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/a0/df0d9389b3ce22f32305dc14cd5b58e94ba253 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/a0/fe90d486989d2ba95ae5ac3aa78db59ff558c1 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/a0/e0d2ff2a91953854e07c3353ef75431c82d782 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/a0/1c074fa34c371e77b93ad8725782ae1d7f1445 due to 'utf-8' codec can't decode byte 0xe7 in position 16: invalid continuation byte
# Skipped ./.git/objects/a0/092b9c98c47f6f6b8b37a1e79cb632ac50d1cb due to 'utf-8' codec can't decode byte 0x8e in position 5: invalid start byte
# Skipped ./.git/objects/ff/2d2b470880cd1ed02883f63545020038b5a4c9 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/ff/987ee8d8e88ecd05e1a0f6bc8f34fb82824654 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/ff/804648a62e9836fbbdc59a960c061201ddc841 due to 'utf-8' codec can't decode byte 0xb3 in position 8: invalid start byte
# Skipped ./.git/objects/ff/7777fcf3327febe09186f355e98ef5cdecfe3a due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/ff/146c4fadcf559f419be3aef2914f6161a3a7e2 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/ff/d28e18a9a2191b468c49328a2c31a952d5c593 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/ff/4d5dd722f88af0683bacfa1c53e9adeacadc3e due to 'utf-8' codec can't decode byte 0xda in position 3: invalid continuation byte
# Skipped ./.git/objects/ff/4a1be129ab1f5fbae5e0ced3c4f4a79e247af5 due to 'utf-8' codec can't decode byte 0xea in position 6: invalid continuation byte
# Skipped ./.git/objects/ff/3ce44fb4adf2122052b06b3d27f361fa2bd8d5 due to 'utf-8' codec can't decode byte 0xda in position 3: invalid continuation byte
# Skipped ./.git/objects/ff/3f061c116703caefc51460d2d746a8024d2b52 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/ff/bd7952d434c96e3b5254c9d51c7767262ca7da due to 'utf-8' codec can't decode byte 0xb2 in position 10: invalid start byte
# Skipped ./.git/objects/b2/8b9bcfb0937b1c022b1e2091b31e87d52fa338 due to 'utf-8' codec can't decode byte 0xb5 in position 2: invalid start byte
# Skipped ./.git/objects/b2/f2cba90efd2d2316165e84cc4372af84d23746 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/b2/e39976aa47208777f12d0cc901e54306f56cf6 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/b2/156350ac818d6563f0daa5a26b9f909ea402f5 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/b2/6e1092d95eedd626df4f459c8433bcc4bd5cb7 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/2a/6d2bbc6639035670e22940f88e4eb4ac2b40e2 due to 'utf-8' codec can't decode byte 0xec in position 2: invalid continuation byte
# Skipped ./.git/objects/2a/cff28841ca418d02d9086f8043578792a90ff0 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/2a/545a130f08ea5f566032ea4f538ea18c57e9c3 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/2a/b47ef7e23417510c1953e2165eb703586789ad due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/2a/8205c574df1e2578e7ce5ca7c4c17cada8d3e5 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/2a/03f9f05cf7bdc58784e0cbc07d7f4fa64593f1 due to 'utf-8' codec can't decode byte 0x83 in position 6: invalid start byte
# Skipped ./.git/objects/91/28563c6c3c27e6aa4fb6307290a8b750463a7c due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/91/54b201365b873edf3d5fb01fca48c45a2e3f4b due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/91/fb6a5235503a2edd6b7556ab2560df1b4cfa7b due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/91/b17bb82eed07b454b11667ff5317805bb87941 due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/91/2d290e3a48ad8bc69797f56f59dbae5267134c due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/91/8d55e40294d034f70ace0c96eb2b08c2a83ac5 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/91/af6521cf8e8368c551c87a5528f1ee51de5000 due to 'utf-8' codec can't decode byte 0xa3 in position 18: invalid start byte
# Skipped ./.git/objects/91/99571dbb2a03fb0ac712b3cb23e7e07e6c885f due to 'utf-8' codec can't decode byte 0xad in position 19: invalid start byte
# Skipped ./.git/objects/81/4b3edf49b8d6058a057aca93832a7c75c139ef due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/81/a90c5e99ee972fcb0ffc928ed3e7131f42a826 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/81/737d54fb879b9a834bedcdedda5000278e1377 due to 'utf-8' codec can't decode byte 0xbb in position 3: invalid start byte
# Skipped ./.git/objects/81/e7ae685340340515a04c80ea0792e3ed8ffd6a due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/81/15a0b7ce41a7d5b1cd7bd854b2b1436bb1e3ae due to 'utf-8' codec can't decode byte 0xdc in position 3: invalid continuation byte
# Skipped ./.git/objects/81/af6793b1a2b8fec86cca08d66ff467fe16e0a7 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/81/6affb09e0318f32a20190890d91a6e970720ad due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/81/8c23d1712bb2c185fea93d0528ef179aae9d6f due to 'utf-8' codec can't decode byte 0xd4 in position 3: invalid continuation byte
# Skipped ./.git/objects/43/2a731bd0b156b024641b04ab49f124391b2939 due to 'utf-8' codec can't decode byte 0x90 in position 3: invalid start byte
# Skipped ./.git/objects/43/ce1e666024ffe19433654b9be76f3983be4e12 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/43/5d17fac55391b8382332400b6daef7ffd6033a due to 'utf-8' codec can't decode byte 0xc3 in position 18: invalid continuation byte
# Skipped ./.git/objects/43/b7c296fb7cdfe702a6acc4e7846235a73985cd due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/43/e6596788f19267dd0a4be3e0f056961802e15d due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/dc/4ba5f9b8b1796405844bbd95d739ac22c876e0 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/dc/02b07a73105275f6a53cea3f79ff9982f9aa1b due to 'utf-8' codec can't decode byte 0xd1 in position 23: invalid continuation byte
# Skipped ./.git/objects/dc/7afc9a7abf1d00059ab8e428650fdea2f27815 due to 'utf-8' codec can't decode byte 0xc9 in position 4: invalid continuation byte
# Skipped ./.git/objects/dc/013f4a8126d76f9ab5ed6afbac3904e1cdb4b6 due to 'utf-8' codec can't decode byte 0xae in position 5: invalid start byte
# ...
# Skipped ./.git/objects/bd/15b3556718cd88806361c571089a3323223475 due to 'utf-8' codec can't decode byte 0x94 in position 2: invalid start byte
# Skipped ./.git/objects/74/8f34ec22afcb24c31c534a66ddc57d000c03a2 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/74/01fbf0032d7690810db8cc85883103a52954c8 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/74/6dcbb3815ade86d1e0e8b8de9ca105c2a9a206 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/31/79535f8e40413785ec32c1c02cdeef809e4628 due to 'utf-8' codec can't decode byte 0x95 in position 2: invalid start byte
# Skipped ./.git/objects/31/1e46683a19dbefce558dd08536fd7f49589c20 due to 'utf-8' codec can't decode byte 0xd1 in position 23: invalid continuation byte
# Skipped ./.git/objects/31/e35964b6b7108442df8d99e2df5525f59307bb due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/31/0ea0c22bebbd922a9885d5901f5a059044de73 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/31/b06a221a468153514e551cdf53fd9939725d0f due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/95/63924948a8503b6ba4d9abbc6541011ab1457c due to 'utf-8' codec can't decode byte 0xdb in position 3: invalid continuation byte
# Skipped ./.git/objects/95/18c8a1455a0a1b68048aa807efbf75a5e86cb1 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/95/29dcd75915a01041ac727452722eed7e58eaff due to 'utf-8' codec can't decode byte 0xdb in position 3: invalid continuation byte
# Skipped ./.git/objects/95/7a941ea456a3c31d1d32114bbb08a106cce237 due to 'utf-8' codec can't decode byte 0x91 in position 3: invalid start byte
# Skipped ./.git/objects/aa/877a74d0fd613ab6466c11cec6bffa770d2140 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/aa/6d14ae55184eb033d547737ba31fa36c195e00 due to 'utf-8' codec can't decode byte 0xd1 in position 22: invalid continuation byte
# Skipped ./.git/objects/aa/4dccc98e4764ca7177cac4ebbe79a16ebfb269 due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/aa/c80c9c12fc69274693eb229416d757c51e4be3 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/6f/aea34a7169583535c51ec9d27337596e9e7006 due to 'utf-8' codec can't decode byte 0xb7 in position 8: invalid start byte
# Skipped ./.git/objects/6f/97cdd9986be0f43da1c157860934934fdacc62 due to 'utf-8' codec can't decode byte 0xa3 in position 18: invalid start byte
# Skipped ./.git/objects/6f/11ef4bcff3b7b336dbfd3c9948037981231385 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/6f/296f7c49069cf8aaf895e054df83c7d4be724d due to 'utf-8' codec can't decode byte 0xca in position 3: invalid continuation byte
# Skipped ./.git/objects/6f/9b8aa61c6f782e4a663ba968ff94750b6b967a due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/6f/cac30a3985e0100cf45b27a46e8df9a7916896 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/26/ccf3cf2a9587e69d49dde1705c59f4b063c539 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/26/74d8ac000956da8b43890c3048363811a7b478 due to 'utf-8' codec can't decode bytes in position 2-3: invalid continuation byte
# Skipped ./.git/objects/26/f70ce4a313e310a4d0bfa33b0d510870e8ce26 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/26/db62060df877067b59e9239b21b869be420407 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/26/5102d7096d1443c76848c3cb392437ee13d907 due to 'utf-8' codec can't decode byte 0x8c in position 2: invalid start byte
# Skipped ./.git/objects/26/49298d9a849ae234803c60ec7d2ce9bec307cd due to 'utf-8' codec can't decode byte 0xdc in position 3: invalid continuation byte
# Skipped ./.git/objects/26/4a168427fb87c81b406e68162a753e79ad950c due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/26/41ffc755138dde571501fed4cebcbeb0d959ae due to 'utf-8' codec can't decode byte 0xda in position 3: invalid continuation byte
# Skipped ./.git/objects/a4/091dbf612806184bea91e7878b7213257879ae due to 'utf-8' codec can't decode byte 0xd5 in position 3: invalid continuation byte
# Skipped ./.git/objects/a4/620443f8b1a59a0b4675a7b79f3dba57cf3c84 due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/a4/b2c7eea9b7fbf83349b4837e9253f8ef44741e due to 'utf-8' codec can't decode byte 0xb5 in position 8: invalid start byte
# Skipped ./.git/objects/a4/b30e1009433757700f72c948bc69537f0e3b8e due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/a4/151a143b517ccb24e75fbd8812e92432736f5a due to 'utf-8' codec can't decode byte 0xd8 in position 3: invalid continuation byte
# Skipped ./.git/objects/a4/dde1238847b4190c2111c69fc110d6e5f5e261 due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/7f/dc32af1b05bfd3c26fc916942cebdde4bd8ec2 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/7f/90fce76158566c43a249747aafa1e90bdf2fd0 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/7f/d56f142831d3081be1ed5fe60d02dd04142ef6 due to 'utf-8' codec can't decode byte 0xe5 in position 2: invalid continuation byte
# Skipped ./.git/objects/7f/37227561e56f52a17ee10f2f0e13dba36dcc1a due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/7f/4bf91a57b10b4c2d3bde76e275584c2a6517d4 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/e9/0be35cdc2d9a2be2cf40d34f1dd8583e8c2635 due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/e9/2fd834ac573a7b7c7cab18e3c2a0b4629d369b due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/e9/13c69428e3028f2d1c584e27f58f687d63cd77 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/e9/fa4fdf8efe0b82e6751a99b05a29092b22b7df due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/e9/bc4610ef8f93e92d23b6edba82384a9d1597a2 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/ad/82a2690291f8b25b3751ed466c3a0f88270a8b due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/ad/fce09a9d0739f0bc579cb4f4d15cddb34ff549 due to 'utf-8' codec can't decode byte 0x90 in position 3: invalid start byte
# Skipped ./.git/objects/ad/9916be39dd7144e7f285f7072b1f7b144eb5d9 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/69/6eb4bd0b4245afa6d0cde2ff530519b24ade3a due to 'utf-8' codec can't decode byte 0xdb in position 3: invalid continuation byte
# Skipped ./.git/objects/69/e464ffb0523e8ca0652496d1d018671927123d due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/69/5e60b29046b2417fa23205d578b2ae360279cc due to 'utf-8' codec can't decode byte 0xd2 in position 3: invalid continuation byte
# Skipped ./.git/objects/69/cd8ee1cc1a2d83beea24a73b0c36a40056d332 due to 'utf-8' codec can't decode byte 0xd2 in position 3: invalid continuation byte
# Skipped ./.git/objects/69/963af8a4cd499c856f669c737f5b7ec55d4657 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/69/0c8218ed0dcbf07d135c6682e7560bbec41fc3 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/29/2b62d66f80a4a9211f01f0fbd9bf1072f497fa due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/29/df7c450a44cbaa52272d0d801bfd215ef8559e due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/29/5241a3595059c1c4c03bfeb5dca9e3c9373926 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/29/28d776e445806b324dca76032208cc4c92dc5d due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/29/adb8641bb5ddee3f0fc99700960e0924426690 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/29/a29c0682c2c31bd9d93c5914ca0e20747bbfe2 due to 'utf-8' codec can't decode byte 0xcd in position 19: invalid continuation byte
# Skipped ./.git/objects/0d/5858319525f29a7c41b8432d0f828a038c3186 due to 'utf-8' codec can't decode byte 0xcb in position 3: invalid continuation byte
# Skipped ./.git/objects/0d/00095a7b54a32f449a49a3ba66c21e212b9520 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/0d/15632d8c749a2260ec12ff8aa5cb9ab2535b5c due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/0d/888a126d4ffce6a73c80c1a3285bb9d70d9c08 due to 'utf-8' codec can't decode byte 0x95 in position 3: invalid start byte
# Skipped ./.git/objects/0d/e74c5d46812d6111af9973fc7cede0fa0cdc08 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/eb/448abf48791bcb67c148ab150998dbc2951128 due to 'utf-8' codec can't decode byte 0x8e in position 5: invalid start byte
# Skipped ./.git/objects/eb/d8b580713429b363d4ae64100ce477766eac24 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/eb/159630c9b4f4ab8bd5fbd2c8702716b83a7989 due to 'utf-8' codec can't decode byte 0xdb in position 3: invalid continuation byte
# Skipped ./.git/objects/eb/5a598405f75de412f45b0d2246a0bacc01a16e due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/eb/af509ccb138b66ff0162e784768f9f70d31b3b due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/eb/2a342dcad44e80733dc08b9c3587c6de3a7846 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/eb/235c75f8551d955c5e3065e8396c76e3daf9a9 due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/eb/f58a91ddd5e9012416bbf86fde968f31939ee8 due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/a2/142897f5b3ce4c670ddbaec9fd70d51198ae91 due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/a2/d550220b407b112079edb8f08b764f65f3bb1d due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/a2/3f6576dc0ac9b913e869d0f954b92349033600 due to 'utf-8' codec can't decode byte 0xdb in position 3: invalid continuation byte
# Skipped ./.git/objects/a2/6b9170c6defae37a715bc67218882c337bd02d due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/a2/d2e8ff1631fd5e8fe77a7af601af1334a2251c due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/a2/e257bb124e540cd056d4b89e24298cbbbabcf9 due to 'utf-8' codec can't decode byte 0xe5 in position 2: invalid continuation byte
# Skipped ./.git/objects/09/7d9f8c751cc02a552725821d84f492a2a39fb0 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/09/78d7455f628694e0479f2a0529eae619b0acad due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/09/62e9c54b3c125ec5f4d19fb0e2832f95eed870 due to 'utf-8' codec can't decode byte 0xb4 in position 2: invalid start byte
# Skipped ./.git/objects/09/eda67eaabf9ccf734d313bbdba1d990f4e11bf due to 'utf-8' codec can't decode byte 0xb0 in position 7: invalid start byte
# Skipped ./.git/objects/09/b16cac31e1ec108e1c00675c56c5c82b267560 due to 'utf-8' codec can't decode byte 0x94 in position 6: invalid start byte
# Skipped ./.git/objects/09/78aa515801acbc99fc7cad8588b50885f387f9 due to 'utf-8' codec can't decode byte 0x85 in position 2: invalid start byte
# Skipped ./.git/objects/09/b15d6c2fc1a6c7f91f8a2780516567ddd62987 due to 'utf-8' codec can't decode byte 0xd2 in position 3: invalid continuation byte
# Skipped ./.git/objects/09/a068da692a8a6d1d8d459ffcf285e39a991767 due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/67/8c415f7fa4d7f08ce914383566b454f74a9d9d due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/67/6bdca9cdb33a08233624441dd9062f8398a8de due to 'utf-8' codec can't decode byte 0xa5 in position 2: invalid start byte
# Skipped ./.git/objects/67/09553d093dbf35e2879f1ca3b21bbbc3dc979a due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/67/41c6c3871c6f900426b4a3eddf5b5a00a5223e due to 'utf-8' codec can't decode byte 0x8d in position 2: invalid start byte
# Skipped ./.git/objects/da/170840eb7879ebd48eeb6b96888475a77c3549 due to 'utf-8' codec can't decode byte 0xb7 in position 9: invalid start byte
# Skipped ./.git/objects/da/b77ccd59fd43828432cdf744b29b6adb92c580 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./.git/objects/da/82a3fb282f0d8efeb0037a80534d1c9adc5683 due to 'utf-8' codec can't decode byte 0xad in position 2: invalid start byte
# Skipped ./S2_CuFe_6Sm/Fe_NEXAFS_S2.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S2_CuFe_6Sm/Cu_REF_NEXAFS.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S2_CuFe_6Sm/Fe_K_NEXAFS_S2.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S2_CuFe_6Sm/Ce_NEXAFS_S1.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S7-NiFe-6Sm/Fe_NEXAFS_S7_data.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S7-NiFe-6Sm/Fe_REF_XAS_edge_derivative.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S7-NiFe-6Sm/Fe_REF_energy_shift.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Found 'Ni_REF_XAS.dat' in: ./S7-NiFe-6Sm/Summary_plots.ipynb
# Skipped ./S7-NiFe-6Sm/Ni_REF_XAS_edge_derivative.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S7-NiFe-6Sm/Ni_NEXAFS_S7_data_derivative.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S7-NiFe-6Sm/Ni_NEXAFS_S7_data.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S7-NiFe-6Sm/Fe_REF_NEXAFS.png due to 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# Skipped ./S7-NiFe-6Sm/__pycache__/functions.cpython-310.pyc due to 'utf-8' codec can't decode byte 0xe9 in position 8: invalid continuation byte
# Skipped ./XRD/Activation ramp/XRD_Ru_CGO_main_CeOx_peak.pdf due to 'utf-8' codec can't decode byte 0xac in position 10: invalid start byte
# /tmp/ipykernel_38396/1259248469.py:85: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
# Reference,Edge Energy (eV),Edge Energy (eV)_PVfit_of 1derivative, Edge Energy (eV)_2derivative
#
# Data saved to Ni_REF_XAS_position_derivative.dat

# %% [markdown]
# ### Fe XAS Ref from literature- Extraction of the edge position

# %%
search_string = "Fe_REF_XAS.dat"

monoE_min = 7109
monoE_max = 7134 
#edge = 7.112
# Fe K-edge is at 7.112 KeV
smooth = "yes"

# Walk through the current directory and subdirectories
for root, dirs, files in os.walk("."):
    for i, file in enumerate(files):
        if search_string in file:
            file_path = os.path.join(root, file)
            
            
print(file_path)


result_df = pd.read_csv(file_path, sep='\t')
#print(result_df.head(4))

cmap = plt.cm.viridis
norm = mcolors.Normalize(vmin=0, vmax=(result_df.shape[1]-1) / 2)
energ_calib_Fe_REF_XAS_list = []
if 'Energy' in result_df.columns:
    # Get a list of columns excluding 'Energy'
    columns_to_process = [col for col in result_df.columns if col != 'Energy']
    
    for column in columns_to_process:
        for idx, value in enumerate(result_df[column]):           
            
            edge_energy = find_edge_position(result_df['Energy'].values, result_df[column].values, monoE_min, monoE_max, smooth)
                  
            color = cmap(norm(idx//2))  # Use the same color for pairs
            
            x = result_df['Energy']
            result_df["I"]= result_df[column] 
            y = -0.0*idx + (result_df["I"])

        energ_calib_Fe_REF_XAS_list.append((column,float(edge_energy)))
print(energ_calib_Fe_REF_XAS_list)

#Save the edge data in a new file
filename = "Fe_REF_XAS_position_derivative.dat"  #'sample_data.dat'

# Open the file in write mode
with open(filename, 'w') as file:
    # Write the header
    file.write('Reference,Edge Energy (eV)\n')
    # Write each tuple in the data
    for condition, energy in energ_calib_Fe_REF_XAS_list:
        file.write(f'{condition},{energy}\n')

print(f'Data saved to {filename}')


# Extract x and y values
x_labels = [item[0] for item in energ_calib_Fe_REF_XAS_list]
y_values = [item[1] for item in energ_calib_Fe_REF_XAS_list]

# Create a scatter plot
plt.scatter(x_labels, y_values)
plt.xticks(rotation=45, ha='right')
plt.ylabel ("Edge energy of the Fe K-edge_derivative / eV")
#plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("Fe REF edge_derivative")
plt.savefig('Fe_REF_XAS_edge_derivative.png')
# Out:
# ./Fe_REF_XAS.dat
# [('Fe foil', 7103.0), ('FeO', 7124.0), ('Fe2O3', 7126.8), ('Fe3O4', 7122.2), ('NiFe2O4', 7126.4)]
# Data saved to Fe_REF_XAS_position_derivative.dat

# %% [markdown]
# ### Cu XAS Ref from literature- Extraction of the edge position

# %%
search_string = "Fe_REF_merged"
var1="ionch1" # diode1 / roiX
var2="mcaRt" # AS_IC / mcaLt

monoE_min = 7.08
monoE_max = 7.13
edge = 7.112
smooth = "yes"
# Fe K-edge is at 7.112 KeV

labeled_files= []
for root, dirs, files in os.walk("."):
    files.sort() 
    for i, file in enumerate(files):
        if search_string in file:
            subfolder_name = os.path.basename(root)
            file_path = os.path.join(root, file)
            label = f"{subfolder_name}_{i % 2 +1}"
            labeled_files.append((file_path, label))
labeled_files.sort()

cmap = plt.cm.viridis
norm = mcolors.Normalize(vmin=0, vmax=len(labeled_files) / 2)
energ_calib_Cu_REF_list = []
for idx, (file_path, label) in enumerate(labeled_files):
    print (label)
    result_df = pd.read_csv(file_path)

    closest_monoE1 = find_closest(monoE_min, result_df['monoE'])
    closest_monoE2 = find_closest(monoE_max, result_df['monoE'])
    signal_min = result_df.loc[result_df['monoE'] == closest_monoE1, f'{var1}/{var2}_mean'].values[0]
    signal_max = result_df.loc[result_df['monoE'] == closest_monoE2, f'{var1}/{var2}_mean'].values[0]
    color = cmap(norm(idx//2))  # Use the same color for pairs

    x = result_df['monoE']
    result_df["I_norm"]=(result_df[f'{var1}/{var2}_mean'] - signal_min)/(signal_max - signal_min)
    y = -0.0*idx + (result_df["I_norm"])
    err = (result_df[f'{var1}/{var2}_std'] - signal_min)/(signal_max - signal_min)
    energy_position_ref_data = find_edge_position(result_df['monoE'].values, result_df["I_norm"].values, monoE_min, monoE_max, smooth)

    #target_value = 0.5
    #idx_before = result_df[result_df["I_norm"] <= target_value].index[-1]
    #idx_after = result_df[result_df["I_norm"] > target_value].index[0]
    #x0, y0 = result_df.loc[idx_before, "I_norm"], result_df.loc[idx_before, 'monoE']
    #x1, y1 = result_df.loc[idx_after, "I_norm"], result_df.loc[idx_after, 'monoE']
    #interpolated_monoE = y0 + (target_value - x0) * (y1 - y0) / (x1 - x0)
    energ_calib_Cu_REF_list.append((label,float(energy_position_ref_data)))


    if label.endswith('_1'):
        plt.plot(x, y, label=label, linewidth=2.5, color=color)
    elif label.endswith('_2'):
        plt.plot(x, y, color=color, linestyle='--', linewidth=0.5, label=label)
    #plt.fill_between(x, y - err,y + err, color=color, alpha=0.2)
#plt.ylim([1.75,2.93])
#plt.xlim([7.15,9.])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("Fe REF - Energy correction")

plt.savefig('Fe_REF_NEXAFS.png')
# Out:
# 002_S7-NiFe-6Sm_Activation_2
# 003_S7-NiFe-6Sm_Reaction_1
# 004_S7-NiFe-6Sm_PM_RT_2
# S7-FeNi-6Sm_Activation_ramp_1

# %%
for (lab, en) in energ_calib_Cu_REF_list:
    plt.scatter(lab, en*1000)
    print(f"{lab}: has the edge at {en:.4f}, the energy shift is {edge-en:.3f}")
plt.xticks(rotation=45, ha='right')
plt.ylabel ("Measured energy of the Fe K-edge / eV")
plt.savefig('Fe_REF_energy_shift.png')
# Out:
# 002_S7-NiFe-6Sm_Activation_2: has the edge at 7.1130, the energy shift is -0.001
# 003_S7-NiFe-6Sm_Reaction_1: has the edge at 7.1140, the energy shift is -0.002
# 004_S7-NiFe-6Sm_PM_RT_2: has the edge at 7.1140, the energy shift is -0.002
# S7-FeNi-6Sm_Activation_ramp_1: has the edge at 7.1130, the energy shift is -0.001

# %% [markdown]
# ## Energy shift calculation for the beamline using data

# %% [markdown]
# ### Plot REF Fe (10 um) from data + Calculation of energy shift of beamline

# %%
search_string = "Fe_REF_merged"
var1="ionch1" # diode1 / roiX
var2="mcaRt" # AS_IC / mcaLt

monoE_min = 7.08
monoE_max = 7.13
edge = 7.112
smooth = "yes"
# Fe K-edge is at 7.112 KeV

labeled_files= []
for root, dirs, files in os.walk("."):
    files.sort() 
    for i, file in enumerate(files):
        if search_string in file:
            subfolder_name = os.path.basename(root)
            file_path = os.path.join(root, file)
            label = f"{subfolder_name}_{i % 2 +1}"
            labeled_files.append((file_path, label))
labeled_files.sort()

cmap = plt.cm.viridis
norm = mcolors.Normalize(vmin=0, vmax=len(labeled_files) / 2)
energ_calib_Cu_REF_list = []
for idx, (file_path, label) in enumerate(labeled_files):
    print (label)
    result_df = pd.read_csv(file_path)

    closest_monoE1 = find_closest(monoE_min, result_df['monoE'])
    closest_monoE2 = find_closest(monoE_max, result_df['monoE'])
    signal_min = result_df.loc[result_df['monoE'] == closest_monoE1, f'{var1}/{var2}_mean'].values[0]
    signal_max = result_df.loc[result_df['monoE'] == closest_monoE2, f'{var1}/{var2}_mean'].values[0]
    color = cmap(norm(idx//2))  # Use the same color for pairs

    x = result_df['monoE']
    result_df["I_norm"]=(result_df[f'{var1}/{var2}_mean'] - signal_min)/(signal_max - signal_min)
    y = -0.0*idx + (result_df["I_norm"])
    err = (result_df[f'{var1}/{var2}_std'] - signal_min)/(signal_max - signal_min)
    energy_position_ref_data = find_edge_position(result_df['monoE'].values, result_df["I_norm"].values, monoE_min, monoE_max, smooth)

    #target_value = 0.5
    #idx_before = result_df[result_df["I_norm"] <= target_value].index[-1]
    #idx_after = result_df[result_df["I_norm"] > target_value].index[0]
    #x0, y0 = result_df.loc[idx_before, "I_norm"], result_df.loc[idx_before, 'monoE']
    #x1, y1 = result_df.loc[idx_after, "I_norm"], result_df.loc[idx_after, 'monoE']
    #interpolated_monoE = y0 + (target_value - x0) * (y1 - y0) / (x1 - x0)
    energ_calib_Cu_REF_list.append((label,float(energy_position_ref_data)))


    if label.endswith('_1'):
        plt.plot(x, y, label=label, linewidth=2.5, color=color)
    elif label.endswith('_2'):
        plt.plot(x, y, color=color, linestyle='--', linewidth=0.5, label=label)
    #plt.fill_between(x, y - err,y + err, color=color, alpha=0.2)
#plt.ylim([1.75,2.93])
#plt.xlim([7.15,9.])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("Fe REF - Energy correction")

plt.savefig('Fe_REF_NEXAFS.png')
# Out:
# 002_S7-NiFe-6Sm_Activation_2
# 003_S7-NiFe-6Sm_Reaction_2
# 004_S7-NiFe-6Sm_PM_RT_2
# S7-FeNi-6Sm_Activation_ramp_2

# %%
for (lab, en) in energ_calib_Cu_REF_list:
    plt.scatter(lab, en*1000)
    print(f"{lab}: has the edge at {en:.4f}, the energy shift is {edge-en:.3f}")
plt.xticks(rotation=45, ha='right')
plt.ylabel ("Measured energy of the Fe K-edge / eV")
plt.savefig('Fe_REF_energy_shift.png')
# Out:
# 002_S7-NiFe-6Sm_Activation_2: has the edge at 7.1140, the energy shift is -0.002
# 003_S7-NiFe-6Sm_Reaction_2: has the edge at 7.1140, the energy shift is -0.002
# 004_S7-NiFe-6Sm_PM_RT_2: has the edge at 7.1140, the energy shift is -0.002
# S7-FeNi-6Sm_Activation_ramp_2: has the edge at 7.1140, the energy shift is -0.002

# %% [markdown]
# ## Energy correction of data using the previous obtained edge shift

# %% [markdown]
# ### Fe K-edge NEXAFS of data- Energy correction

# %%
search_string = "Fe_NEXAFS_merged"

energy_shifts = [-0.001, -0.002,-0.002,-0.001]

labeled_files= []
for root, dirs, files in os.walk("."):
    files.sort() 
    for i, file in enumerate(files):
        if search_string in file:
            subfolder_name = os.path.basename(root)
            file_path = os.path.join(root, file)
            label = f"{subfolder_name}_{i % 2 +1}"
            labeled_files.append((file_path, label))
labeled_files.sort()

for idx,(file_path, label) in enumerate(labeled_files):
    print (label)
    result_df = pd.read_csv(file_path)
    result_df["monoE"] = result_df["monoE"] + energy_shifts[idx]
    result_df.to_csv(file_path[:-4]+"_EC.dat")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 energy_shifts = [-0.001, -0.002,-0.002,-0.001]
#       5 labeled_files= []
# ----> 6 for root, dirs, files in os.walk("."):
#       7     files.sort()
#       8     for i, file in enumerate(files):
#
# NameError: name 'os' is not defined

# %% [markdown]
# ### Fe K-edge NEXAFS- Edge position of merged data

# %%
search_string = "Fe_NEXAFS_merged"
search_string_2 = "EC"
var1="roi5" # diode1 / roiX / ionch1
var2="mcaLt" # AS_IC / mcaLt mcaRt

monoE_min = 7.10
monoE_max = 7.13
#edge = 7.112
smooth = "yes"
# Fe K-edge is at 7.112 KeV

labeled_files= []
for root, dirs, files in os.walk("."):
    files.sort() 
    for i, file in enumerate(files):
        if search_string in file and search_string_2 in file:
            subfolder_name = os.path.basename(root)
            file_path = os.path.join(root, file)
            label = f"{subfolder_name}_{i % 2 +1}"
            labeled_files.append((file_path, label))
labeled_files.sort()

cmap = plt.cm.viridis
norm = mcolors.Normalize(vmin=0, vmax=len(labeled_files) / 2)
energ_calib_Fe_NEXAFS_list = []
for idx, (file_path, label) in enumerate(labeled_files):
    print (file_path)
    result_df = pd.read_csv(file_path)

    closest_monoE1 = find_closest(monoE_min, result_df['monoE'])
    closest_monoE2 = find_closest(monoE_max, result_df['monoE'])
    signal_min = result_df.loc[result_df['monoE'] == closest_monoE1, f'{var1}/{var2}_mean'].values[0]
    signal_max = result_df.loc[result_df['monoE'] == closest_monoE2, f'{var1}/{var2}_mean'].values[0]
    color = cmap(norm(idx//2))  # Use the same color for pairs

    x = result_df['monoE']
    result_df["I_norm"]=(result_df[f'{var1}/{var2}_mean'] - signal_min)/(signal_max - signal_min)
    y = -0.0*idx + (result_df["I_norm"])
    err = (result_df[f'{var1}/{var2}_std'] - signal_min)/(signal_max - signal_min)
    
    edge_position = find_edge_position(result_df['monoE'].values, result_df["I_norm"].values, monoE_min, monoE_max, smooth)
    
    #target_min = result_df.loc[result_df['monoE'] == closest_monoE1, 'I_norm'].values[0]
    #target_max = result_df.loc[result_df['monoE'] == closest_monoE2, 'I_norm'].values[0]
    #target_value = (target_max - target_min)/2
 
    ## this adds a constrain that the energy edge value should be between the monoE_min and monoE_max values 
    #idx_before = result_df[(result_df["I_norm"] <= target_value) & 
    #                   (result_df['monoE'] >= monoE_min) & 
    #                   (result_df['monoE'] <= monoE_max)].index[-1]

    #idx_after = result_df[(result_df["I_norm"] > target_value) & 
    #                  (result_df['monoE'] >= monoE_min) & 
    #                  (result_df['monoE'] <= monoE_max)].index[0]
    
    #x0, y0 = result_df.loc[idx_before, "I_norm"], result_df.loc[idx_before, 'monoE']
    #x1, y1 = result_df.loc[idx_after, "I_norm"], result_df.loc[idx_after, 'monoE']
    #interpolated_monoE = y0 + (target_value - x0) * (y1 - y0) / (x1 - x0)
    
    energ_calib_Fe_NEXAFS_list.append((label,float(edge_position)))
    
    
    if label.endswith('_1'):
        #plt.plot(x, y, label=label, linewidth=2.5, color=color)

        smoothed_data = savgol_filter(y, 5, 3)
        first_derivative = np.gradient(smoothed_data)
        plt.plot(x, first_derivative, label=label, linewidth=2.5, color=color)

    elif label.endswith('_2'):
        #plt.plot(x, y, color=color, linestyle='--', linewidth=0.5, label=label)

        smoothed_data = savgol_filter(y, 5, 3)
        first_derivative = np.gradient(smoothed_data)
        plt.plot(x, first_derivative, color=color, linestyle='--', linewidth=0.5, label=label)
    #plt.fill_between(x, y - err,y + err, color=color, alpha=0.2)
print(energ_calib_Fe_NEXAFS_list)




plt.xlim([7.1,7.13])

###############
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("Fe NEXAFS S7 data")

plt.savefig('Fe_NEXAFS_S7_data.png')

# %% [markdown]
# ### Ni K-edge NEXAFS of data- Energy correction

# %%
#search_string = "Ni_*_merged"

energy_shifts = [-0.001, -0.002,-0.002,-0.001]

labeled_files= []
for root, dirs, files in os.walk("."):
    files.sort() 
    for i, file in enumerate(files):
        if "Ni_" and "_merged" in file and "Fe" not in file and "Ce" not in file:
            subfolder_name = os.path.basename(root)
            file_path = os.path.join(root, file)
            label = f"{subfolder_name}_{i % 2 +1}"
            labeled_files.append((file_path, label))
labeled_files.sort()
print(labeled_files)

for idx,(file_path, label) in enumerate(labeled_files):
    print (label)
    result_df = pd.read_csv(file_path)
    result_df["monoE"] = result_df["monoE"] + energy_shifts[idx]
    result_df.to_csv(file_path[:-4]+"_EC.dat")

# %% [markdown]
# ### Ni K-edge NEXAFS -Edge position of merged data

# %%
#search_string = "Ni_*_merged" #there are NEXAFS and EXAFS file. I will filter this in another way
search_string_2 = "EC"
var1="roi4" # diode1 / roiX / ionch1
var2="mcaLt" # AS_IC / mcaLt mcaRt

monoE_min = 8.333
monoE_max = 8.352 #8.352 #8.3455
smooth = "yes"


# Ni K-edge is at 8.333 KeV

labeled_files= []
for root, dirs, files in os.walk("."):
    files.sort() 
    for i, file in enumerate(files):
        if "Ni_" and "_merged" in file and "Fe" not in file and "Ce" not in file and search_string_2 in file:
        
        #if search_string in file and search_string_2 in file:
            subfolder_name = os.path.basename(root)
            file_path = os.path.join(root, file)
            label = f"{subfolder_name}_{i % 2 +1}"
            labeled_files.append((file_path, label))
labeled_files.sort()

cmap = plt.cm.viridis
norm = mcolors.Normalize(vmin=0, vmax=len(labeled_files) / 2)
energ_calib_Ni_XAFS_list = []

for idx, (file_path, label) in enumerate(labeled_files):
    print (file_path)
    result_df = pd.read_csv(file_path)

    closest_monoE1 = find_closest(monoE_min, result_df['monoE'])
    closest_monoE2 = find_closest(monoE_max, result_df['monoE'])
    signal_min = result_df.loc[result_df['monoE'] == closest_monoE1, f'{var1}/{var2}_mean'].values[0]
    signal_max = result_df.loc[result_df['monoE'] == closest_monoE2, f'{var1}/{var2}_mean'].values[0]
    color = cmap(norm(idx//2))  # Use the same color for pairs

    x = result_df['monoE']
    result_df["I_norm"]=(result_df[f'{var1}/{var2}_mean'] - signal_min)/(signal_max - signal_min)
    y = -0.0*idx + (result_df["I_norm"])
    err = (result_df[f'{var1}/{var2}_std'] - signal_min)/(signal_max - signal_min)
    
    edge_position = find_edge_position(result_df['monoE'].values, result_df["I_norm"].values, monoE_min, monoE_max, smooth)
            
    # Use the detected edge position to refine your calibration or other calculations
    #edge_energy = result_df['monoE'].iloc[edge_position_idx]  # Energy at the detected edge position

    #target_min = result_df.loc[result_df['monoE'] == closest_monoE1, 'I_norm'].values[0]
    #target_max = result_df.loc[result_df['monoE'] == closest_monoE2, 'I_norm'].values[0]
    #target_value = (target_max - target_min)/2
       
    ## this adds a constrain that the energy edge value should be between the monoE_min and monoE_max values 
    #idx_before = result_df[(result_df["I_norm"] <= target_value) & 
    #                   (result_df['monoE'] >= monoE_min) & 
    #                   (result_df['monoE'] <= monoE_max)].index[-1]

    #idx_after = result_df[(result_df["I_norm"] > target_value) & 
    #                  (result_df['monoE'] >= monoE_min) & 
    #                  (result_df['monoE'] <= monoE_max)].index[0]
    
    
    #x0, y0 = result_df.loc[idx_before, "I_norm"], result_df.loc[idx_before, 'monoE']
    #x1, y1 = result_df.loc[idx_after, "I_norm"], result_df.loc[idx_after, 'monoE']
    #interpolated_monoE = y0 + (target_value - x0) * (y1 - y0) / (x1 - x0)
    energ_calib_Ni_XAFS_list.append((label,float(edge_position)))
    
    
    if label.endswith('_1'):
        plt.plot(x, y, label=label, linewidth=2.5, color=color)
    elif label.endswith('_2'):
        plt.plot(x, y, color=color, linestyle='--', linewidth=1.5, label=label)
    #plt.fill_between(x, y - err,y + err, color=color, alpha=0.2)
print(energ_calib_Ni_XAFS_list)

plt.ylim([-0.9,1.2])
plt.xlim([8.3,8.38])
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.title("Ni NEXAFS S7 data_derivative")

plt.savefig('Ni_NEXAFS_S7_data_derivative.png')
# Out:
# ./002_S7-NiFe-6Sm_Activation/Data_Ni_EXAFS_merged_scans_16_18_EC.dat
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 45
#      42 y = -0.0*idx + (result_df["I_norm"])
#      43 err = (result_df[f'{var1}/{var2}_std'] - signal_min)/(signal_max - signal_min)
# ---> 45 edge_position = find_edge_position(result_df['monoE'].values, result_df["I_norm"].values, monoE_min, monoE_max, smooth)
#      47 # Use the detected edge position to refine your calibration or other calculations
#      48 #edge_energy = result_df['monoE'].iloc[edge_position_idx]  # Energy at the detected edge position
#      49
#    (...)
#      65 #x1, y1 = result_df.loc[idx_after, "I_norm"], result_df.loc[idx_after, 'monoE']
#      66 #interpolated_monoE = y0 + (target_value - x0) * (y1 - y0) / (x1 - x0)
#      67 energ_calib_Ni_XAFS_list.append((label,float(edge_position)))
#
# TypeError: find_edge_position() missing 1 required positional argument: 'polyorder'
