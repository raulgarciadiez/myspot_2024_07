# %% [markdown]
# ### Siempre ejecutar esta celda

# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# # Calibración de temperaturas en capilar (2024/07/22)

# %%
calib_temp = pd.read_csv("calibr_Temp_Myspot_2024_07.csv")
plt.scatter(calib_temp["T_sp"], calib_temp["T_sam"], label = "Measured data")

linear_trend = LinearRegression()
linear_trend.fit(calib_temp[['T_sp']], calib_temp['T_sam'])
a = linear_trend.intercept_
b = linear_trend.coef_[0]
print (a,b)
T_sp_new = np.arange(0, 801, 10).reshape(-1, 1)
T_sam_linear_pred = linear_trend.predict(T_sp_new)
plt.plot(T_sp_new, T_sam_linear_pred, color='red', label='Linear trend')

plt.xlabel("T_sp")
plt.ylabel("T_sam")
plt.legend(loc=0)
# Out:
# 7.272864176078826 0.7717086591369823
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# #### Which temperature I set to reach the desired temperature inside the capillary?

# %%
# Define the desired T_sam value
desired_T_sam = 500.0

# Calculate the required T_sp
a,b = 7.272864176078826, 0.7717086591369823

required_T_sp = (desired_T_sam - a) / b

print(f"The required T_sp to achieve T_sam = {desired_T_sam} is {required_T_sp:.1f}")
# Out:
# The required T_sp to achieve T_sam = 500.0 is 638.5

# %%
T_sam_list = np.array([200,220,240,260,280,300,320,340,360,380,400,550, 600])
for T_sam, T_sp in zip(T_sam_list,(T_sam_list - a)/b):
    print ("For T_sam=", T_sam,"°C; set T_sp=",  round(T_sp,1))
# Out:
# For T_sam= 200 °C; set T_sp= 249.7
# For T_sam= 220 °C; set T_sp= 275.7
# For T_sam= 240 °C; set T_sp= 301.6
# For T_sam= 260 °C; set T_sp= 327.5
# For T_sam= 280 °C; set T_sp= 353.4
# For T_sam= 300 °C; set T_sp= 379.3
# For T_sam= 320 °C; set T_sp= 405.2
# For T_sam= 340 °C; set T_sp= 431.2
# For T_sam= 360 °C; set T_sp= 457.1
# For T_sam= 380 °C; set T_sp= 483.0
# For T_sam= 400 °C; set T_sp= 508.9
# For T_sam= 550 °C; set T_sp= 703.3
# For T_sam= 600 °C; set T_sp= 768.1

# %%
print("esto va a funcionar de locos")
# Out:
# esto va a funcionar de locos
